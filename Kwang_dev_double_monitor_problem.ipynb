# %%
import cv2
import time
import matplotlib.pyplot as plt
import numpy as np
import sys
import win32api, win32con, win32gui
from mss import mss

# %%
from launcher import NoxManager

# %%
config = {
    'nox_size' : (600, 800)
}

# %%
manager = NoxManager(config=config)
# Out:
# -------------------------------------
# Run Nox Application and Press Any Key
# Now Find Nox Position
# on scanning... 99.71%
#
# Refining Nox Position
# on scanning... 99.98%
#
# Finished
#
# ------------------------------------------
# Run Girl's Frontier and Move to Main Menu
# Now Find Menu Positions
#
# Compat Pos Obtained
# Restore Pos Obtained
# Formation Pos Obtained
#
# Finished

# %%
manager.nox_pos
# Out:
# array([  217, -1823])

# %%
win32api.GetCursorPos()
# Out:
# (-1819, 195)

# %%
double_left = manager.monitor['left']
double_top = manager.monitor['top']

# %%
double_monitor_nox_pos = [double_left + manager.nox_pos[1], double_top + manager.nox_pos[0]]

# %%
win32api.SetCursorPos(double_monitor_nox_pos)

# %%
manager.monitor
# Out:
# {'height': 1080, 'left': -1920, 'top': 0, 'width': 5760}

# %%
manager.nox_monitor
# Out:
# {'height': 600, 'left': 299, 'top': 254, 'width': 800}

# %%
from util import *

# %%
screen = get_screen(manager.sct, manager.monitor)

# %%
screen.shape
# Out:
# (1080, 5760, 4)

# %%
screen

# %%
manager.nox_pos
# Out:
# array([254, 299])

# %%
manager.nox_monitor
# Out:
# {'height': 600, 'left': 299, 'top': 254, 'width': 800}

# %%
manager.monitor
# Out:
# {'height': 1080, 'left': -1920, 'top': 0, 'width': 5760}

# %%
screen = get_screen(manager.sct, manager.nox_monitor)

plt.imshow(screen)
plt.show()

# %%
manager.nox_monitor['left'] += manager.monitor['left']
manager.nox_monitor['top'] += manager.monitor['top']

# %%
manager.nox_monitor
# Out:
# {'height': 600, 'left': -1621, 'top': 254, 'width': 800}
